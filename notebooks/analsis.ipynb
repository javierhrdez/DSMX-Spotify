# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


# %matplotlib inline

# %%
music = pd.read_csv("data/db.csv")

# %%
music.describe()
# Out:
#         Unnamed: 0  acousticness  artist_followers  artist_popularity  \
# count  1782.000000   1782.000000      1.782000e+03        1782.000000
# mean    890.500000      0.251427      6.975011e+06          79.515152
# std     514.563407      0.243876      8.098636e+06          12.127877
# min       0.000000      0.000015      1.280000e+02           1.000000
# 25%     445.250000      0.052425      1.485058e+06          73.000000
# 50%     890.500000      0.166500      3.417183e+06          81.000000
# 75%    1335.750000      0.392000      1.135218e+07          88.000000
# max    1781.000000      0.983000      4.118997e+07         100.000000
#
#        danceability    duration_ms       energy     explicit  \
# count   1782.000000    1782.000000  1782.000000  1782.000000
# mean       0.662088  214280.111111     0.656771     0.157688
# std        0.138502   41996.515733     0.173960     0.364550
# min        0.215000   37640.000000     0.041300     0.000000
# 25%        0.582000  190033.750000     0.539250     0.000000
# 50%        0.686000  211440.000000     0.680000     0.000000
# 75%        0.759000  234302.500000     0.791000     0.000000
# max        0.953000  433520.000000     0.989000     1.000000
#
#        instrumentalness          key     liveness     loudness         mode  \
# count       1782.000000  1782.000000  1782.000000  1782.000000  1782.000000
# mean           0.013326     5.111672     0.183998    -6.031875     0.641975
# std            0.082695     3.635928     0.152810     2.490064     0.479554
# min            0.000000     0.000000     0.021500   -20.652000     0.000000
# 25%            0.000000     1.000000     0.092600    -7.094000     0.000000
# 50%            0.000000     5.000000     0.126000    -5.592500     1.000000
# 75%            0.000035     8.000000     0.224000    -4.375000     1.000000
# max            0.927000    11.000000     0.983000     0.175000     1.000000
#
#        speechiness        tempo  time_signature  track_popularity      valence
# count  1782.000000  1782.000000     1782.000000       1782.000000  1782.000000
# mean      0.084534   122.479505        3.914141         55.080808     0.563164
# std       0.076348    30.248953        0.333312         26.800010     0.233030
# min       0.023200    53.894000        1.000000          0.000000     0.048500
# 25%       0.038000    97.565250        4.000000         33.000000     0.383500
# 50%       0.054500   118.979500        4.000000         65.000000     0.567500
# 75%       0.099225   142.180750        4.000000         75.000000     0.763000
# max       0.717000   212.117000        5.000000        100.000000     0.977000

# %%
sns.set(style="ticks")

# Initialize the figure with a logarithmic x axis
f, ax = plt.subplots(figsize=(7, 6))
ax.set_xscale("log")

# Load the example planets dataset
planets = sns.load_dataset("planets")
print(planets.head())

# Plot the orbital period with horizontal boxes
sns.boxplot(x="distance", y="method", data=planets,
            whis="range", palette="vlag")

# Add in points to show each observation
sns.swarmplot(x="distance", y="method", data=planets,
              size=2, color=".3", linewidth=0)

# Tweak the visual presentation
ax.xaxis.grid(True)
ax.set(ylabel="")
sns.despine(trim=True, left=True)
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
music.head()
# Out:
#    Unnamed: 0  acousticness    album_name                              artist  \
# 0           0       0.18700     El Dorado                      Shakira,Maluma
# 1           1       0.40000  Primera Cita                                CNCO
# 2           2       0.00431  Vente Pa' Ca                 Ricky Martin,Maluma
# 3           3       0.55100       Energía  J Balvin,Pharrell Williams,BIA,Sky
# 4           4       0.05590      Motivan2              Zion & Lennox,J Balvin
#
#    artist_followers                                      artist_genres  \
# 0        15589793.0  colombian pop,dance pop,latin,latin pop,mexica...
# 1         5182695.0    boy band,latin,latin pop,pop,reggaeton,tropical
# 2         4453926.0  dance pop,latin,latin pop,mexican pop,pop,trop...
# 3        13303709.0                                latin,pop,reggaeton
# 4         3187460.0  latin,latin hip hop,latin pop,pop,reggaeton,tr...
#
#    artist_popularity  danceability  duration_ms  energy   ...     liveness  \
# 0               83.0         0.852     195840.0   0.773   ...        0.159
# 1               78.0         0.761     222560.0   0.838   ...        0.176
# 2               73.0         0.663     259196.0   0.920   ...        0.101
# 3               92.0         0.508     205600.0   0.687   ...        0.126
# 4               83.0         0.832     209453.0   0.772   ...        0.440
#
#    loudness                                             lyrics  mode  \
# 0    -2.921  cuando estás bien te alejas de mí te sientes s...   0.0
# 1    -3.073  qué bien se ve me trae loco su figura ese traj...   0.0
# 2    -4.070  ven, te cuento de una vez tu descanso está en ...   0.0
# 3    -4.361  a ella le gus- a ella le gus- a ella le gus- a...   1.0
# 4    -5.429  el sólo verte me dan ganas (precisamente en ca...   1.0
#
#    speechiness    tempo  time_signature                  track_name  \
# 0       0.0776  102.034             4.0     Chantaje (feat. Maluma)
# 1       0.0502   93.974             4.0  Reggaetón Lento (Bailemos)
# 2       0.2260   99.935             4.0                Vente Pa' Ca
# 3       0.3260  180.044             4.0                      Safari
# 4       0.1000   96.016             4.0   Otra Vez (feat. J Balvin)
#
#    track_popularity  valence
# 0              78.0    0.907
# 1              77.0    0.710
# 2              75.0    0.533
# 3              15.0    0.555
# 4              76.0    0.704
#
# [5 rows x 23 columns]

# %%
music.columns.values
# Out:
# array(['Unnamed: 0', 'acousticness', 'album_name', 'artist',
#        'artist_followers', 'artist_genres', 'artist_popularity',
#        'danceability', 'duration_ms', 'energy', 'explicit',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'lyrics',
#        'mode', 'speechiness', 'tempo', 'time_signature', 'track_name',
#        'track_popularity', 'valence'], dtype=object)

# %%
#canciones que no traen letras :(
#music.columns[music.isna().any()].tolist()
music[music['lyrics'].isnull()]
# Out:
#       Unnamed: 0  acousticness                                   album_name  \
# 1183        1183        0.0309                                         True
# 1386        1386        0.0268                               God is a woman
# 1444        1444        0.0233                                    Sweetener
# 1612        1612        0.8810  Bohemian Rhapsody (The Original Soundtrack)
#
#              artist  artist_followers  \
# 1183         Avicii        12450045.0
# 1386  Ariana Grande        25843377.0
# 1444  Ariana Grande        25843430.0
# 1612          Queen        13870723.0
#
#                                   artist_genres  artist_popularity  \
# 1183  big room,dance pop,edm,pop,tropical house               83.0
# 1386                dance pop,pop,post-teen pop              100.0
# 1444                dance pop,pop,post-teen pop              100.0
# 1612                             glam rock,rock               94.0
#
#       danceability  duration_ms  energy   ...     liveness  loudness  lyrics  \
# 1183         0.545     255093.0   0.780   ...       0.0828    -4.867     NaN
# 1386         0.604     197573.0   0.673   ...       0.1870    -5.979     NaN
# 1444         0.602     197547.0   0.658   ...       0.2370    -5.934     NaN
# 1612         0.215      41455.0   0.870   ...       0.9760   -10.920     NaN
#
#       mode  speechiness    tempo  time_signature        track_name  \
# 1183   0.0       0.0436  125.014             4.0       Hey Brother
# 1386   1.0       0.0545  144.971             4.0    God is a woman
# 1444   1.0       0.0558  145.031             4.0    God is a woman
# 1612   1.0       0.3510  144.877             3.0  Ay-Oh - Live Aid
#
#       track_popularity  valence
# 1183              25.0    0.458
# 1386              30.0    0.287
# 1444              87.0    0.268
# 1612              75.0    0.462
#
# [4 rows x 23 columns]

# %%
def grafico_atributo(df,atributo,color,file):

    fig, ax = plt.subplots(figsize=(20,25))
    sns.set(style="whitegrid")
    sns.set(font_scale = 2.5)
    sns.set_color_codes("pastel")
    track_ordenados = df
    #track_ordenados = music.sort_values(by=[atributo], ascending=False)
    #primeros = music.head().sort_values(by=[atributo], ascending=False)
    #ultimos = music.tail().sort_values(by=[atributo], ascending=False)
    #track_ordenados = pd.concat([primeros, ultimos])
    
    ax = sns.barplot(x=track_ordenados[atributo], y=track_ordenados['track_name'] +' (' + track_ordenados['artist'] + ')', data=track_ordenados,palette=sns.dark_palette(color, n_colors=50, reverse=True), ci=None)
    #ax = sns.barplot(x=track_ordenados[atributo], y=track_ordenados['track_name'] +' (' + track_ordenados['artist'] + ')', data=track_ordenados,palette=sns.dark_palette(color, n_colors=50, reverse=True))
    plt.ylabel('Artista', fontsize=26)
    plt.xlabel('Valor', fontsize=26)
    plt.title(atributo.title(), fontsize=26)

    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(28)
        tick.label.set_fontweight("bold")
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(28)
        tick.label.set_fontweight("bold")

    #for p in ax.patches:
    #    width = p.get_width()
    #    ax.text(width + 3  ,
    #            p.get_y() + p.get_height()/1.4,
    #            "%d" % width,
    #            ha="center", fontsize=15)
    #sns.despine()
    plt.savefig(file)
    plt.plot()

# %%
#track más populares
track_ordenados = music.sort_values(by=["track_popularity"], ascending=False)[:10] 
#track_ordenados
grafico_atributo(track_ordenados,"track_popularity","purple","presentacion//images//track_popularity_first20.jpg")

# %%
#track más populares
track_ordenados = music.sort_values(by=["track_popularity"], ascending=False)[-20:]
track_ordenados
#grafico_atributo(track_ordenados,"track_popularity","purple","presentacion//images//track_popularity_last20.jpg")
# Out:
#       Unnamed: 0  acousticness  \
# 752          752        0.4000
# 760          760        0.8700
# 114          114        0.4490
# 777          777        0.1880
# 544          544        0.5220
# 1045        1045        0.0417
# 543          543        0.4330
# 126          126        0.4380
# 527          527        0.5090
# 821          821        0.0722
# 824          824        0.3330
# 653          653        0.5940
# 512          512        0.0402
# 506          506        0.0312
# 834          834        0.0949
# 924          924        0.1250
# 974          974        0.1650
# 1015        1015        0.3350
# 1030        1030        0.2260
# 828          828        0.4280
#
#                                              album_name  \
# 752                                        Primera Fila
# 760                                 Alejandro Fernandez
# 114                                         El Aferrado
# 777                             El Momento (Remastered)
# 544                                  Ni Diablo Ni Santo
# 1045                                   Scooby Doo Pa Pa
# 543                                  Ni Diablo Ni Santo
# 126                                         El Aferrado
# 527                             Esta Noche Se Me Olvida
# 821                     La bikina (Inspirado en "COCO")
# 824   El corrido de Miguel Rivera (Inspirado en "COCO")
# 653                                  Ni Diablo Ni Santo
# 512                                             Lo Digo
# 506                                               J-Boy
# 834                                      Red Pill Blues
# 924                                 El Burrito De Belen
# 974                                           Oye Mujer
# 1015                           To The Faithful Departed
# 1030                                        Antes De Ti
# 828                     Remember Me (Dúo) [From "Coco"]
#
#                                  artist  artist_followers  \
# 752                   Vicente Fernández         1900200.0
# 760                 Alejandro Fernandez         2032866.0
# 114   Julión Álvarez y su Norteño Banda         1109466.0
# 777                           Nacha Pop          132462.0
# 544   Julión Álvarez y su Norteño Banda         1109465.0
# 1045                            Dj Kass           25573.0
# 543   Julión Álvarez y su Norteño Banda         1109465.0
# 126   Julión Álvarez y su Norteño Banda         1109466.0
# 527   Julión Álvarez y su Norteño Banda         1109465.0
# 821                       Karol Sevilla           57219.0
# 824                              Bronco          645228.0
# 653   Julión Álvarez y su Norteño Banda         1109466.0
# 512         Carlos Rivera,Gente De Zona          782678.0
# 506                             Phoenix         1424771.0
# 834                        Maroon 5,SZA        16712734.0
# 924                              Juanes         2173437.0
# 974                              Raymix          121089.0
# 1015                    The Cranberries         1485058.0
# 1030                        Mon Laferte         2319369.0
# 828           Miguel,Natalia Lafourcade         2155206.0
#
#                                           artist_genres  artist_popularity  \
# 752                           grupera,mariachi,ranchera               73.0
# 760   grupera,latin,latin arena pop,latin pop,mexica...               77.0
# 114                                             norteno                1.0
# 777   cantautor,rock en espanol,spanish new wave,spa...               56.0
# 544                                             norteno                1.0
# 1045                                   chilean hardcore               55.0
# 543                                             norteno                1.0
# 126                                             norteno                1.0
# 527                                             norteno                1.0
# 821                                     latin viral pop               45.0
# 824   banda,cumbia,grupera,latin,latin pop,norteno,r...               66.0
# 653                                             norteno                1.0
# 512         latin,latin arena pop,latin pop,mexican pop               76.0
# 506   alternative dance,dance-punk,indie pop,indie r...               68.0
# 834                                                 pop               88.0
# 924   colombian pop,cumbia,dance pop,latin,latin pop...               77.0
# 974                                           nu-cumbia               64.0
# 1015                                irish rock,pop rock               74.0
# 1030                        latin alternative,latin pop               73.0
# 828    dance pop,pop,pop rap,r&b,rap,urban contemporary               81.0
#
#       danceability  duration_ms  energy   ...     liveness  loudness  \
# 752          0.477     292733.0   0.584   ...       0.9320    -7.837
# 760          0.389     246227.0   0.528   ...       0.3710    -8.923
# 114          0.755     161907.0   0.521   ...       0.0855    -5.854
# 777          0.382     247693.0   0.482   ...       0.0880   -11.605
# 544          0.546     202013.0   0.385   ...       0.2770    -5.394
# 1045         0.906     146000.0   0.708   ...       0.1590    -3.678
# 543          0.722     179107.0   0.497   ...       0.3800    -4.996
# 126          0.678     219373.0   0.606   ...       0.1110    -5.829
# 527          0.661     200427.0   0.392   ...       0.3390    -5.330
# 821          0.568     176880.0   0.951   ...       0.3020    -1.439
# 824          0.532     237000.0   0.646   ...       0.1270    -6.339
# 653          0.743     209147.0   0.472   ...       0.0833    -5.805
# 512          0.677     227907.0   0.937   ...       0.1210    -4.176
# 506          0.526     248213.0   0.918   ...       0.1370    -6.692
# 834          0.799     199853.0   0.604   ...       0.1240    -5.134
# 924          0.681     191640.0   0.903   ...       0.5650    -5.106
# 974          0.728     259139.0   0.591   ...       0.2750    -5.778
# 1015         0.461     296200.0   0.528   ...       0.0689    -7.109
# 1030         0.501     242240.0   0.625   ...       0.2780    -4.594
# 828          0.612     164453.0   0.545   ...       0.4520    -6.695
#
#                                                  lyrics  mode  speechiness  \
# 752   te mire, estabas tan bonita... tan sensual te ...   1.0       0.0385
# 760   si tú supieras que tu recuerdo me acaricia com...   1.0       0.0339
# 114   si quieres ir a lazar a las mulas de moreno si...   1.0       0.0602
# 777   lucha de gigantes convierte el aire en gas nat...   0.0       0.0330
# 544   lo mejor que te pasó se supone que eso era all...   1.0       0.0583
# 1045  dj kass mr. worldwide (jajaja) to' el mundo en...   0.0       0.2440
# 543   lo mejor que te pasó se supone que eso era all...   1.0       0.0378
# 126   soy un hombre campesino que ha bajado a la ciu...   1.0       0.0283
# 527   lo mejor que te pasó se supone que eso era all...   1.0       0.0458
# 821   solitaria camina la bikina y la gente se pone ...   1.0       0.0888
# 824   cruzaron por el umbral de la muerte, un perro ...   1.0       0.0532
# 653   andabas en los brazos de otro amor como si nad...   1.0       0.0360
# 512   hablo por mi, no hablo por dios se que me escu...   0.0       0.0555
# 506   ah! something in the middle of the side of the...   1.0       0.0465
# 834   say say say, hey hey now baby oh mama, don't p...   0.0       0.0634
# 924   las puertas se cerraron mi madre se quedo con ...   1.0       0.0577
# 974   oye mujer lo que has provocado en mí no tengo ...   0.0       0.0457
# 1015  do-be-da, do-be-da do-be-da, do-be-da do-be-da...   1.0       0.0269
# 1030  me puedes ver en mis pupilas no se puede escon...   0.0       0.0260
# 828   remember me, though i have to say goodbye reme...   1.0       0.0335
#
#         tempo  time_signature  \
# 752   101.790             4.0
# 760   173.706             4.0
# 114    97.545             3.0
# 777   113.523             4.0
# 544   112.547             3.0
# 1045  120.948             4.0
# 543   128.044             4.0
# 126   100.022             3.0
# 527    74.944             4.0
# 821   159.948             3.0
# 824   149.873             4.0
# 653   127.956             4.0
# 512   104.958             4.0
# 506    98.004             4.0
# 834   109.999             4.0
# 924   179.883             4.0
# 974   181.987             4.0
# 1015  187.137             3.0
# 1030   91.951             4.0
# 828    84.985             4.0
#
#                                              track_name  track_popularity  \
# 752                               Estos Celos - En Vivo               0.0
# 760                                      Si Tú Supieras               0.0
# 114                               Pongámonos De Acuerdo               0.0
# 777                                   Lucha De Gigantes               0.0
# 544                             Esta Noche Se Me Olvida               0.0
# 1045                                   Scooby Doo Pa Pa               0.0
# 543                               Afuera Está Lloviendo               0.0
# 126                                  El Amor De Su Vida               0.0
# 527                             Esta Noche Se Me Olvida               0.0
# 821                     La bikina - Inspirado en "COCO"               0.0
# 824   El corrido de Miguel Rivera - Inspirado en "Coco"               0.0
# 653                                       Y Me Pregunto               0.0
# 512                                             Lo Digo               0.0
# 506                                               J-Boy               0.0
# 834                                      What Lovers Do               0.0
# 924                                 El Burrito De Belén               0.0
# 974                                           Oye Mujer               0.0
# 1015                                   When You're Gone               0.0
# 1030                                        Antes De Ti               0.0
# 828                     Remember Me (Dúo) - From "Coco"               0.0
#
#       valence
# 752     0.651
# 760     0.283
# 114     0.976
# 777     0.129
# 544     0.779
# 1045    0.550
# 543     0.596
# 126     0.911
# 527     0.827
# 821     0.791
# 824     0.403
# 653     0.858
# 512     0.523
# 506     0.634
# 834     0.405
# 924     0.899
# 974     0.945
# 1015    0.370
# 1030    0.313
# 828     0.562
#
# [20 rows x 23 columns]

# %%
#20 más bailables
#track_ordenados = music.sort_values(by=["danceability"], ascending=False)[:5] + music.sort_values(by=["danceability"], ascending=False)[-5:]
track_ordenados = pd.concat([ music.sort_values(by=["danceability"], ascending=False)[:5],  music.sort_values(by=["danceability"], ascending=False)[-5:]])
#track_ordenados
grafico_atributo(track_ordenados,"danceability","red","presentacion//images//bailables.jpg")

#grafico_atributo("danceability","red")

# %%
#10 más acusticos
#track_ordenados = music.sort_values(by=["acousticness"], ascending=False)[:10]
primeros =  music.sort_values(by=["acousticness"], ascending=False)[:5]
#ultimos = music.sort_values(by=["acousticness"], ascending=False)[-5:]
#track_ordenados = pd.concat([primeros, ultimos  ])
track_ordenados = primeros
grafico_atributo(track_ordenados,"acousticness","red","presentacion//images//acusticos.jpg")

# %%
#10 menos acusticos
track_ordenados = music.sort_values(by=["acousticness"], ascending=False)[-5:]
#track_ordenados
grafico_atributo(track_ordenados,"acousticness","red","presentacion//images//menos_acustico.jpg")

# %%
#10 más larga
primeros =  music.sort_values(by=["duration_ms"], ascending=False)[:5]
ultimos = music.sort_values(by=["duration_ms"], ascending=False)[-5:]
track_ordenados = pd.concat([primeros, ultimos  ])
grafico_atributo(track_ordenados,"duration_ms","yellow","presentacion//images//mas_larga.jpg")

# %%
#10 más energetica
#track_ordenados = music.sort_values(by=["energy"], ascending=False)[:10]
primeros =  music.sort_values(by=["energy"], ascending=False)[:5]
ultimos = music.sort_values(by=["energy"], ascending=False)[-5:]
track_ordenados = pd.concat([primeros, ultimos])
grafico_atributo(track_ordenados,"energy","pink","presentacion//images//energetica.jpg")

# %%
#10 más instrumental
#track_ordenados = music.sort_values(by=["instrumentalness"], ascending=False)[:10]
primeros =  music.sort_values(by=["instrumentalness"], ascending=False)[:5]
ultimos = music.sort_values(by=["instrumentalness"], ascending=False)[-5:]
track_ordenados = pd.concat([primeros, ultimos])
grafico_atributo(track_ordenados,"instrumentalness","orange","presentacion//images//mas_instrumental.jpg")

# %%
#10 menos instrumental
track_ordenados = music.sort_values(by=["instrumentalness"], ascending=False)[-10:]
primeros =  music.sort_values(by=["instrumentalness"], ascending=False)[:5]
ultimos = music.sort_values(by=["instrumentalness"], ascending=False)[-5:]
track_ordenados = pd.concat([primeros, ultimos])
grafico_atributo(track_ordenados,"instrumentalness","orange","presentacion//images//menos_instrumental.jpg")

# %%
#10 más liveness
#track_ordenados = music.sort_values(by=["liveness"], ascending=False)[:10]
primeros =  music.sort_values(by=["liveness"], ascending=False)[:5]
ultimos = music.sort_values(by=["liveness"], ascending=False)[-5:]
track_ordenados = pd.concat([primeros, ultimos])
#track_ordenados
grafico_atributo(track_ordenados,"liveness","gray","presentacion//images//mas_liveness.jpg")

# %%
#Speechiness
primeros =  music.sort_values(by=["speechiness"], ascending=False)[:5]
ultimos = music.sort_values(by=["speechiness"], ascending=False)[-5:]
track_ordenados = pd.concat([primeros, ultimos])
grafico_atributo(track_ordenados,"speechiness","lime","presentacion//images//mas_speechiness.jpg")

# %%
#10 más valence
#track_ordenados = music.sort_values(by=["valence"], ascending=False)[:10]
primeros =  music.sort_values(by=["valence"], ascending=False)[:5]
ultimos = music.sort_values(by=["valence"], ascending=False)[-5:]
track_ordenados = pd.concat([primeros, ultimos])
grafico_atributo(track_ordenados,"valence","crimson","presentacion//images//valence.jpg")

# %%
music = music.dropna(subset=['lyrics'])
music['words'] = music.lyrics.str.strip().str.split('[\W_]+')
#music['words']
rows = list()
for row in music[['words']].iterrows():
    r = row[1]
    for word in r.words:
        rows.append((word))

words = pd.DataFrame(rows, columns=['word'])

words = words[words.word.str.len() > 0]
words['word'] = words.word.str.lower()



counts = words\
    .word.value_counts()\
    .to_frame()\
    .rename(columns={'word':'n_w'})
counts
# Out:
#               n_w
# i           17465
# me          14124
# que         14077
# you         13295
# no          10897
# a           10805
# the          9590
# y            8832
# la           6961
# te           6819
# de           6284
# it           6120
# to           5734
# oh           5640
# t            5299
# and          5177
# yo           4966
# my           4888
# el           4885
# en           4059
# m            3831
# lo           3789
# s            3581
# on           3334
# in           3226
# tu           3139
# tú           3122
# that         3080
# yeah         3077
# we           3058
# ...           ...
# maletas         1
# loqueando       1
# yellowtail      1
# museum          1
# godly           1
# rapero          1
# concluya        1
# tylenol         1
# semitone        1
# oreo            1
# stimulate       1
# descubrir       1
# atraviesan      1
# acomodo         1
# gaticas         1
# atadura         1
# mower           1
# dreamteam       1
# longevity       1
# repetimos       1
# semanas         1
# skillz          1
# disfrutas       1
# liriquilla      1
# cocina          1
# respetarla      1
# arrebatao       1
# evian           1
# fave            1
# trunk           1
#
# [21132 rows x 1 columns]

# %%
#import nltk
#nltk.download()
#python -m nltk.downloader <collection|package|all>
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
#from wordcloud import WordCloud

# %%
stopwords_spanish = stopwords.words('spanish')
stopwords_english = stopwords.words('english')

# %%
for a_stopword in stopwords_spanish:
    if a_stopword in counts.index:
        counts = counts.drop(a_stopword)
        
for a_stopword in stopwords_english:
    if a_stopword in counts.index:
        counts = counts.drop(a_stopword)

# %%
top_20 = counts.head(20)
top_20
# Out:
#          n_w
# oh      5640
# yeah    3077
# si      2878
# know    2451
# baby    2419
# like    2362
# love    2283
# got     1764
# quiero  1763
# pa      1729
# amor    1612
# let     1382
# go      1136
# one     1122
# get     1111
# eh      1074
# na      1055
# say     1035
# cause   1032
# sé      1031

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.barplot(x="n_w", y=top_20.index, data=top_20, palette=sns.light_palette("yellow", n_colors=20, reverse=True))
plt.ylabel("")
plt.xlabel('Frecuencia', fontsize=20)
plt.title('Top 20 palabras en canciones en playlist', fontsize=25)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(20) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
for p in ax.patches:
    width = p.get_width()
    ax.text(width + 3  ,
            p.get_y() + p.get_height()/1.4,
            "%d" % width,
            ha="center", fontsize=15)
sns.despine()
plt.savefig('top_words_in_songs.jpg')
plt.plot();

# %%
vector_genres = list()
for genre in music['artist_genres'].dropna().str.split(','):
    #vector_genres.append(genre)
    if genre:
        vector_genres += genre
vector_genres        
generos = pd.DataFrame(vector_genres, columns=['genre'])
generos        
#print(vector_genres)
#for i in set(vector_genres):
#    print(i,"--->",vector_genres.count(i))
generos = generos\
    .genre.value_counts()\
    .to_frame()\
    .rename(columns={'genre':'n_g'})

generos.head()
# Out:
#            n_g
# pop        713
# latin      456
# dance pop  449
# latin pop  405
# reggaeton  250

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.barplot(x="n_g", y=generos.index, data=generos, palette=sns.light_palette("red", n_colors=len(generos), reverse=True))
plt.ylabel("")
plt.xlabel('Frecuencia', fontsize=20)
plt.title('Top 20 generos en canciones', fontsize=25)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(20) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(20)
for p in ax.patches:
    width = p.get_width()
    ax.text(width + 0.5  ,
            p.get_y() + p.get_height()/1.4,
            "%d" % width,
            ha="center", fontsize=15)
sns.despine()
plt.savefig('top_generos.jpg')
plt.plot();

# %%
# palabras más comunes por genero

words_by_genre = pd.DataFrame()
for row in music[['artist_genres','words']].dropna().iterrows():
    genre = row[1].artist_genres.split(',')
    words = row[1].words
    for g in genre:
        words_by_genre = words_by_genre.append({'genre':g,'words':words},ignore_index=True)

df_wbg = words_by_genre.groupby(['genre']).apply(lambda x: x['words'].sum())
df = pd.concat([df_wbg,generos], axis=1, sort=True).sort_values(by=['n_g'], ascending=False)[:5] # primeros 5
#df = pd.concat([df_wbg,generos], axis=1, sort=True).sort_values(by=['n_g'], ascending=False)[-5:] # ultimos 5

for i, v in df[0].items():
    #print(i,v)
    rows = list()
    for word in v:
        rows.append((word))
    words = pd.DataFrame(rows, columns=['word'])
    words = words[words.word.str.len() > 0]
    words['word'] = words.word.str.lower()
    counts = words\
        .word.value_counts()\
        .to_frame()\
        .rename(columns={'word':'n_w'})
    
    for a_stopword in stopwords_spanish:
        if a_stopword in counts.index:
            counts = counts.drop(a_stopword)

    for a_stopword in stopwords_english:
        if a_stopword in counts.index:
            counts = counts.drop(a_stopword)    
    #print("-"*40)
    #print(i)
    #print(counts.head(10))
    counts = counts.head(10)
    fig, ax = plt.subplots(figsize=(20,10))
    ax = sns.barplot(x="n_w", y=counts.index, data=counts, palette=sns.light_palette("yellow", n_colors=10, reverse=True))
    plt.ylabel("")
    plt.xlabel('Frecuencia', fontsize=20)
    plt.title('Top 10 palabras en ' + i, fontsize=25)
    for tick in ax.xaxis.get_major_ticks():
        tick.label.set_fontsize(20) 
    for tick in ax.yaxis.get_major_ticks():
        tick.label.set_fontsize(20)
    for p in ax.patches:
        width = p.get_width()
        ax.text(width + 0.8  ,
                p.get_y() + p.get_height()/1.4,
                "%d" % width,
                ha="center", fontsize=15)
    sns.despine()
    plt.plot();

# %%
# densidad lirica ?????

music['duration_s'] = music['duration_ms']/1000.0
music['amount_of_words'] = music['words'].str.len()
music['lyric_density'] = music['amount_of_words']/music['duration_s']
#amount_of_words
#grafico_atributo("amount_of_words","blue")
#densidad lyryca    
#grafico_atributo("lyric_density","blue")

# %%
# calculando otra vez densidad lyrica y léxica

stopset = set(stopwords_spanish + stopwords_english)
music['tokens'] = pd.Series(dtype=object)
for index, row in music.iterrows():
    try:
        #print(row['lyrics'])
        tokens = word_tokenize(row['lyrics'])
        tokens_wo_stopwords = [word for word in tokens if not word in stopset]
        music.at[index, 'tokens'] = tokens_wo_stopwords
        music.at[index, 'le_d'] = ( len(tokens_wo_stopwords) / len(tokens) ) * 100
        music.at[index, 'ly_d'] = len(tokens) / row['duration_s']
        music.at[index, 'n_words'] = len(tokens)
        music.at[index, 'n_words_no_rep'] = len(list(set(tokens)))
    except: # songs without lyrics throw exceptions, i'm lazy
        continue

music['le_d'] = music['le_d'].fillna(0)
music['ly_d'] = music['ly_d'].fillna(0)

# %%
# DENSIDAD LÉXICA
#grafico_atributo("le_d","blue")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-39-c39d2eacc8e4> in <module>
#       1 # DENSIDAD LÉXICA
# ----> 2 grafico_atributo("le_d","blue")
#
# TypeError: grafico_atributo() missing 2 required positional arguments: 'color' and 'file'

# %%
#grafico_atributo("ly_d","purple")

# %%
#grafico_atributo("n_words","pink")

# %%
#grafico_atributo("n_words_no_rep","pink")

# %%
words_by_genre = pd.DataFrame()
for row in music[['artist_genres','lyrics','duration_s']].dropna().iterrows():
    #print(row)
    genre = row[1].artist_genres.split(',')
    lyrics = row[1].lyrics
    duration_s = row[1].duration_s
    for g in genre:
        words_by_genre = words_by_genre.append({'genre':g,'lyrics':lyrics,'duration_s':duration_s},ignore_index=True)

#print(words_by_genre.head(10))
df_wbg = words_by_genre.groupby(['genre']).apply(lambda x: x['lyrics'].sum())
df_time = words_by_genre.groupby(['genre']).apply(lambda x: x['duration_s'].mean())
df = pd.concat([df_wbg,generos,df_time ], axis=1, sort=True).sort_values(by=['n_g'], ascending=False)[:5] # primeros 5
#print(df.head(5))

df['tokens'] = pd.Series(dtype=object)
for index, row in df.iterrows():
    try:
        tokens = word_tokenize(row[0])
        #print(tokens)
        tokens_wo_stopwords = [word for word in tokens if not word in stopset]
        df.at[index, 'tokens'] = tokens_wo_stopwords
        df.at[index, 'le_d'] = ( len(tokens_wo_stopwords) / len(tokens) ) * 100
        df.at[index, 'ly_d'] = len(tokens) / row[1]
        df.at[index, 'n_words'] = len(tokens)
        df.at[index, 'n_words_no_rep'] = len(list(set(tokens)))
    except: # songs without lyrics throw exceptions, i'm lazy
        continue


df['le_d'] = df['le_d'].fillna(0)
df['ly_d'] = df['ly_d'].fillna(0)
df
# Out:
#                                                            0  n_g           1  \
# pop        cuando estás bien te alejas de mí te sientes s...  713  214.512951
# latin      cuando estás bien te alejas de mí te sientes s...  456  215.918184
# dance pop  cuando estás bien te alejas de mí te sientes s...  449  211.031214
# latin pop  cuando estás bien te alejas de mí te sientes s...  405  215.210059
# reggaeton  qué bien se ve me trae loco su figura ese traj...  250  216.352484
#
#                                                       tokens       le_d  \
# pop        [bien, alejas, sientes, sola, siempre, ahí, gu...  58.067423
# latin      [bien, alejas, sientes, sola, siempre, ahí, gu...  55.296393
# dance pop  [bien, alejas, sientes, sola, siempre, ahí, gu...  57.353914
# latin pop  [bien, alejas, sientes, sola, siempre, ahí, gu...  53.790059
# reggaeton  [bien, trae, loco, figura, trajecito, corto, q...  58.231857
#
#                   ly_d   n_words  n_words_no_rep
# pop        1505.489522  322947.0         11272.0
# latin       775.979108  167548.0          9297.0
# dance pop   960.303437  202654.0          7532.0
# latin pop   629.552357  135486.0          7692.0
# reggaeton   554.553374  119979.0          7252.0

# %%
#ax = sns.boxplot(x=df["le_d"])

#fig, ax = plt.subplots(figsize=(30,15))
#sns.barplot(x=df.index, y=df['ly_d'], palette="deep", ax=ax)
#ax.axhline(0, color="k", clip_on=False)
#ax.set_ylabel("Qualitative")
fig, ax = plt.subplots(figsize=(30,15))


ax = sns.barplot(x="le_d", y=df.index, data=df, label="Lexical", color="b")

# Plot the crashes where alcohol was involved
ax = sns.barplot(x="ly_d", y=df.index, data=df,label="Lyrical", color="r", ax=ax)

for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(24) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(24)
# Add a legend and informative axis label
ax.legend(ncol=2, loc="lower right", frameon=True, fontsize=20)
ax.set(xlim=(0, 70), ylabel="",xlabel="Densidad Léxica/Lirica")
sns.despine(left=True, bottom=True)

# %%
fig, ax = plt.subplots(figsize=(30,15))
ax = sns.boxplot(x=music["le_d"], y=music.index, data=df, orient='h', palette=sns.light_palette("yellow", n_colors=20, reverse=True),showfliers=False)
ax = sns.swarmplot(x=music["le_d"], y=df.index, data=df, orient='h', size=10, color="xkcd:charcoal")
plt.xlabel('# of words', fontsize=20)
plt.ylabel('Album', fontsize=20)
plt.title('Distribution of number of words over albums', fontsize=25)
for tick in ax.xaxis.get_major_ticks():
    tick.label.set_fontsize(20) 
for tick in ax.yaxis.get_major_ticks():
    tick.label.set_fontsize(20) 
#plt.savefig('img/n_words_by_album.jpg')
plt.plot();

# %%
#pd.melt(music, value_vars=['artist_genres'],id_vars=['le_d', 'ly_d'])
music_subset = music[['acousticness','danceability','energy','instrumentalness','liveness','speechiness','valence','track_name']]
music_subset = music_subset.track_name.str.split(',', expand=True)\
.merge(music_subset, right_index = True, left_index = True)\
.drop(["track_name"], axis = 1)\
.melt(id_vars = ['acousticness','danceability','energy','instrumentalness','liveness','speechiness','valence'], value_name = "track_name")\
.drop("variable", axis = 1)\
.dropna()

# %%
music_subset
# Out:
#       acousticness  danceability  energy  instrumentalness  liveness  \
# 0          0.18700         0.852   0.773          0.000030    0.1590
# 1          0.40000         0.761   0.838          0.000000    0.1760
# 2          0.00431         0.663   0.920          0.000017    0.1010
# 3          0.55100         0.508   0.687          0.000003    0.1260
# 4          0.05590         0.832   0.772          0.000486    0.4400
# 5          0.19800         0.736   0.964          0.000002    0.3360
# 6          0.14200         0.776   0.669          0.000000    0.2190
# 7          0.41400         0.748   0.524          0.000000    0.1110
# 8          0.07600         0.899   0.626          0.000000    0.0631
# 9          0.16500         0.681   0.594          0.000003    0.1340
# 10         0.07840         0.476   0.718          0.000010    0.1220
# 11         0.16700         0.761   0.829          0.000000    0.1890
# 12         0.03400         0.818   0.803          0.000000    0.1530
# 13         0.33800         0.783   0.623          0.000000    0.0975
# 14         0.32400         0.431   0.452          0.000000    0.3130
# 15         0.40600         0.720   0.763          0.000000    0.1800
# 16         0.54700         0.760   0.838          0.000001    0.0664
# 17         0.07860         0.724   0.904          0.000000    0.2260
# 18         0.13200         0.730   0.701          0.000000    0.1510
# 19         0.09980         0.721   0.687          0.000000    0.0679
# 20         0.02440         0.680   0.954          0.000000    0.1120
# 21         0.42600         0.773   0.819          0.000000    0.0679
# 22         0.04080         0.648   0.738          0.000000    0.2920
# 23         0.09830         0.772   0.547          0.000004    0.1070
# 24         0.09350         0.819   0.913          0.000037    0.1610
# 25         0.62100         0.728   0.563          0.000000    0.1790
# 26         0.00784         0.791   0.619          0.004230    0.3510
# 27         0.25600         0.772   0.909          0.000000    0.2550
# 28         0.05920         0.490   0.485          0.000000    0.3370
# 29         0.07360         0.608   0.798          0.000000    0.1560
# ...            ...           ...     ...               ...       ...
# 2191       0.34000         0.784   0.728          0.000000    0.2220
# 2230       0.05520         0.609   0.668          0.000000    0.1670
# 2234       0.18200         0.446   0.648          0.000011    0.3480
# 2333       0.13200         0.738   0.814          0.000010    0.1260
# 2352       0.06420         0.893   0.745          0.000000    0.0943
# 2363       0.22200         0.819   0.457          0.000000    0.1280
# 2369       0.15200         0.722   0.790          0.000000    0.0349
# 2588       0.03930         0.659   0.717          0.000000    0.0769
# 2632       0.03890         0.743   0.917          0.000006    0.2650
# 2692       0.35500         0.517   0.843          0.000000    0.1560
# 2723       0.88900         0.347   0.187          0.000001    0.1100
# 2839       0.16500         0.792   0.895          0.000000    0.0501
# 2870       0.34200         0.834   0.753          0.000000    0.1080
# 2880       0.19400         0.653   0.809          0.000000    0.1650
# 3055       0.11400         0.618   0.845          0.000000    0.4150
# 3266       0.11200         0.521   0.934          0.000015    0.1960
# 3313       0.15300         0.841   0.798          0.000003    0.0618
# 3385       0.28000         0.724   0.647          0.000000    0.1020
# 3392       0.00850         0.691   0.716          0.000009    0.2630
# 3416       0.08930         0.761   0.672          0.000010    0.1400
# 3476       0.01660         0.766   0.881          0.000002    0.3470
# 3515       0.22900         0.717   0.653          0.000000    0.1010
# 3516       0.04210         0.726   0.554          0.000000    0.1060
# 3668       0.09710         0.805   0.582          0.000000    0.1630
# 3772       0.25500         0.502   0.786          0.000000    0.6500
# 3812       0.27000         0.639   0.869          0.000000    0.0802
# 4008       0.05520         0.609   0.668          0.000000    0.1670
# 4410       0.03890         0.743   0.917          0.000006    0.2650
# 4617       0.16500         0.792   0.895          0.000000    0.0501
# 5590       0.27000         0.639   0.869          0.000000    0.0802
#
#       loudness  speechiness  valence  \
# 0       -2.921       0.0776   0.9070
# 1       -3.073       0.0502   0.7100
# 2       -4.070       0.2260   0.5330
# 3       -4.361       0.3260   0.5550
# 4       -5.429       0.1000   0.7040
# 5       -2.147       0.1290   0.9530
# 6       -4.933       0.0638   0.6610
# 7       -5.599       0.0338   0.6610
# 8       -4.228       0.2920   0.8730
# 9       -7.028       0.2820   0.5350
# 10      -5.309       0.0576   0.1420
# 11      -3.203       0.0681   0.8130
# 12      -4.282       0.0797   0.6320
# 13      -6.126       0.0800   0.4470
# 14      -5.165       0.0346   0.7420
# 15      -4.068       0.0523   0.7420
# 16      -3.828       0.0529   0.7450
# 17      -3.354       0.0966   0.8460
# 18      -5.885       0.1060   0.7850
# 19      -6.682       0.0782   0.8250
# 20      -1.823       0.1190   0.5210
# 21      -5.946       0.1180   0.5850
# 22      -5.883       0.2470   0.6030
# 23      -6.373       0.0541   0.0957
# 24      -3.059       0.0427   0.5360
# 25      -8.053       0.1340   0.3520
# 26      -5.886       0.0532   0.3710
# 27      -3.225       0.1660   0.6940
# 28      -6.237       0.0406   0.1960
# 29      -5.092       0.0432   0.5010
# ...        ...          ...      ...
# 2191    -4.549       0.0539   0.7130
# 2230    -4.284       0.0367   0.8110
# 2234    -6.773       0.3000   0.6960
# 2333    -4.414       0.0999   0.4830
# 2352    -3.105       0.0571   0.8720
# 2363    -6.962       0.1350   0.2730
# 2369    -4.867       0.2410   0.4340
# 2588    -4.202       0.0581   0.7100
# 2632    -3.941       0.0968   0.4910
# 2692    -3.520       0.1530   0.7490
# 2723   -11.369       0.0514   0.2030
# 2839    -3.112       0.0589   0.7940
# 2870    -3.011       0.0486   0.4620
# 2880    -4.057       0.0474   0.5500
# 3055     0.175       0.1320   0.4860
# 3266    -2.740       0.0550   0.8440
# 3313    -4.206       0.2290   0.5910
# 3385    -5.642       0.0658   0.4350
# 3392    -5.985       0.0351   0.5070
# 3416    -5.887       0.2120   0.4370
# 3476    -5.158       0.1370   0.6740
# 3515    -5.634       0.0658   0.4120
# 3516    -5.290       0.0917   0.3350
# 3668    -5.657       0.0627   0.3070
# 3772    -4.378       0.3170   0.7390
# 3812    -4.024       0.1470   0.7670
# 4008    -4.284       0.0367   0.8110
# 4410    -3.941       0.0968   0.4910
# 4617    -3.112       0.0589   0.7940
# 5590    -4.024       0.1470   0.7670
#
#                                              track_name
# 0                               Chantaje (feat. Maluma)
# 1                            Reggaetón Lento (Bailemos)
# 2                                          Vente Pa' Ca
# 3                                                Safari
# 4                             Otra Vez (feat. J Balvin)
# 5                                          La Bicicleta
# 6                                           Traicionera
# 7                                                Closer
# 8                                           Shaky Shaky
# 9                                               Starboy
# 10                                      Let Me Love You
# 11                            Ay Mi Dios (feat. Pitbull
# 12                                            24K Magic
# 13                                     Don't Wanna Know
# 14                                           Adiós Amor
# 15              Rockabye (feat. Sean Paul & Anne-Marie)
# 16                     Me Llamas (feat. Maluma) - Remix
# 17                                     DUELE EL CORAZON
# 18                                       Borro Cassette
# 19                               Dile Que Tu Me Quieres
# 20                                   Andas En Mi Cabeza
# 21                                     I Feel It Coming
# 22                                         Side To Side
# 23                                         Cuatro Babys
# 24                                               My Way
# 25           We Don't Talk Anymore (feat. Selena Gomez)
# 26                                            One Dance
# 27                                           Vacaciones
# 28                                  In the Name of Love
# 29                Cold Water (feat. Justin Bieber & MØ)
# ...                                                 ...
# 2191                 Pharrell Williams & Ariana Grande)
# 2230                                              Quavo
# 2234                              Zebra Katz & RAY BLK)
# 2333                            Camila Cabello & Quavo)
# 2352                             Katy Perry & Big Sean)
# 2363                                  Ozuna & Arcangel)
# 2369                          PARTYNEXTDOOR & D.R.A.M.)
# 2588                       Florida Georgia Line & watt)
# 2632                                               Amor
# 2692                                            Navidad
# 2723                                             London
# 2839                                                  2
# 2870                                             Cazzu)
# 2880                           Macklemore & Dan Caplen)
# 3055               feat. Zhavia Ward) - from Deadpool 2
# 3266                                        Me Escuchan
# 3313                                   Ozuna & Cardi B)
# 3385                                               next
# 3392                                  Diplo & Labrinth)
# 3416                                        Kanye West)
# 3476   feat. Bantu) - Spider-Man: Into the Spider-Verse
# 3515                                               next
# 3516                                          i'm bored
# 3668                            Dj Luian & Mambo Kings)
# 3772         Logic & Ty Dolla $ign feat. X Ambassadors)
# 3812                                            Farruko
# 4008                     Chance the Rapper & Lil Wayne)
# 4410                                 Amor (feat. Wisin)
# 4617              3 (feat. Jason Derulo & De La Ghetto)
# 5590                                     Zion & Lennox]
#
# [1815 rows x 9 columns]

# %%
fig, ax = plt.subplots(figsize=(20,10))
ax = sns.boxplot(data=music_subset, orient="h", palette="Set2")

# %% [markdown]
# ## REFERENCIAS

# %% [markdown]
# https://towardsdatascience.com/data-data-1fedfac91c79
# https://github.com/alexing/datadata/blob/master/drexler_data_exploration.ipynb
# https://github.com/alexing/datadata/blob/master/drexler_dataset_builder.ipynb
# https://developer.spotify.com/documentation/web-api/
